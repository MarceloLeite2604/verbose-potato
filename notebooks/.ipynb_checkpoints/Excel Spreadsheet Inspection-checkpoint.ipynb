# %% [markdown]
# # Excel Spreadsheet Inpection

# %% [markdown]
# ## Spreadsheet Cells Information Gathering

# %%
import openpyxl
import json

spreadsheet_location = 'input-files/ferramenta_ghg_protocol_v2025.0.1.xlsx'

def extract_spreadsheet_data(file_path):
    wb = openpyxl.load_workbook(file_path, data_only=False)  # Load formulas
    data = {}

    sheetnames = wb.sheetnames[4:5]

    for sheet in sheetnames:
        ws = wb[sheet]
        sheet_data = []

        for row in ws.iter_rows():
            for cell in row:
                cell_data = {
                    "cell": cell.coordinate,
                    "value": cell.value if cell.value else None,
                    "formula": cell.formula if cell.data_type == 'f' and cell.formula else None,
                    "metadata": {}
                }

                # Extract comments
                if cell.comment:
                    cell_data["metadata"]["comment"] = cell.comment.text

                if cell.fill and cell.fill.bgColor and cell.fill.bgColor and cell.fill.bgColor.rgb and cell.fill.bgColor.rgb != '000000':
                    print(f'Cell: {cell.coordinate} background color: {cell.fill.bgColor}.')

                sheet_data.append(cell_data)
        
        data[sheet] = sheet_data

    return data

# Example usage
structured_data = extract_spreadsheet_data(spreadsheet_location)

# Save structured data to a JSON file for further processing
# with open("spreadsheet_data.json", "w") as f:
#     json.dump(structured_data, f, indent=4)

# print(json.dumps(structured_data, indent=2))
# Out:
# /home/marcelo/Documents/git/MarceloLeite2604/verbose-potato/venv/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/marcelo/Documents/git/MarceloLeite2604/verbose-potato/venv/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# Cell: A1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X1 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X2 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X3 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X4 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X5 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X6 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X7 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X8 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X9 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X10 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X11 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: B12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: C12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: D12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: E12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: F12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: G12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: H12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: I12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: J12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: K12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: L12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: M12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: N12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: O12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: P12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: Q12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: R12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: S12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: T12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: U12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: V12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: W12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: X12 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# Cell: A13 background color: <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 39
#      36     return data
#      38 # Example usage
# ---> 39 structured_data = extract_spreadsheet_data(spreadsheet_location)
#      41 # Save structured data to a JSON file for further processing
#      42 # with open("spreadsheet_data.json", "w") as f:
#      43 #     json.dump(structured_data, f, indent=4)
#      44
#      45 # print(json.dumps(structured_data, indent=2))
#
# Cell In[2], line 21, in extract_spreadsheet_data(file_path)
#      16 for row in ws.iter_rows():
#      17     for cell in row:
#      18         cell_data = {
#      19             "cell": cell.coordinate,
#      20             "value": cell.value if cell.value else None,
# ---> 21             "formula": cell.formula if cell.data_type == 'f' else None,
#      22             "metadata": {}
#      23         }
#      25         # Extract comments
#      26         if cell.comment:
#
# AttributeError: 'Cell' object has no attribute 'formula'

# %%
print(documents[418])
